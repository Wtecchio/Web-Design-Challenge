# %%
import pandas as pd

# %%
df = pd.read_csv("cities.csv")

# %%
df.to_html('cities.html')
# Out:
#      Unnamed: 0                   City      Lat       Lng  Max Temp  Humidity  \
# 0             0                Ushuaia -54.8000  -68.3000     38.82        64
# 1             1        Arraial do Cabo -22.9661  -42.0278     73.36        78
# 2             2                  Orlik  52.5178   99.8250     42.64        84
# 3             3                Mataura -46.1927  168.8643     44.47        97
# 4             4  Chapada dos Guimarães -15.4606  -55.7497     87.46        22
# ..          ...                    ...      ...       ...       ...       ...
# 541         541               Semporna   4.4818  118.6112     78.57        84
# 542         542                Magaria  12.9983    8.9099     86.07        59
# 543         543            Ciudad Real  39.0000   -4.0000     88.14        24
# 544         544              Maniitsoq  65.4167  -52.9000     40.71        92
# 545         545   Vila Franca do Campo  37.7167  -25.4333     78.19        89
#
# ...
